# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

# %%
data = pd.read_csv('panda.csv')
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data.iloc[0].index
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Student Code', 'Degree', 'Student Name', 'Mid', 'Quiz 1', 'Quiz 2',
#        'Best of Quizzes', 'Assignment 1', 'Assignment 2',
#        'Best of Assignments', 'Total Sessional (50)', 'Final (50)',
#        'Total (100)', 'Grade'],
#       dtype='object')

# %%
data.tail(10)
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 38  022-14-110229  BS(CS)   Sadaquat Rafique    9     6.0     6.0
# 39  022-14-110107  BS(CS)        Sania Iqbal   28     4.0     4.0
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 41  022-14-110225  BS(CS)      Shariqa Ahmad   20     7.0     6.0
# 42  022-14-110587  BS(CS)      Sumbul Rehman   28     5.0     6.0
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 38                6           5.0           7.0                    7
# 39                4           9.0          11.0                   11
# ...

# %%
data.tail()
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 43                9           6.0           8.0                    8
# 44                7           9.0           NaN                    9
# 45                9           9.0           NaN                    9
# 46                8           8.0          10.0                   10
# 47                9           5.0           7.0                    7
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 43                    45        34.0           79     B
# ...

# %%
data.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
data[data.groupby('Best of Assignments').count()>2]
# Out:
#      Student Code  Degree         Student Name   Mid  Quiz 1  Quiz 2  \
# 0             NaN     NaN                  NaN   NaN     NaN     NaN
# 1             NaN     NaN                  NaN   NaN     NaN     NaN
# 2             NaN     NaN                  NaN   NaN     NaN     NaN
# 3             NaN     NaN                  NaN   NaN     NaN     NaN
# 4             NaN     NaN                  NaN   NaN     NaN     NaN
# 5             NaN     NaN                  NaN   NaN     NaN     NaN
# 6             NaN     NaN                  NaN   NaN     NaN     NaN
# 7   022-14-110388  BS(CS)     Aneebullah Niazi  26.0     9.0     6.0
# 8   022-14-110601  BS(CS)       Areesha Sohail  19.0     9.0     4.0
# 9   022-14-110599  BS(CS)              Arsalan  28.0     8.0     6.0
# 10  022-14-110214  BS(CS)  Fatima Haider Warsi  30.0     8.0     7.0
# 11  022-14-110591  BS(CS)          Habib Ullah  28.0     8.0     5.0
# 12            NaN     NaN                  NaN   NaN     NaN     NaN
# ...

# %%
persons = pd.DataFrame({
    'name': ['Shahzad','Taha','Fatima','Asad','Ali'],
    'age':np.random.randint(1,40,size=[5]),
    'percent': np.random.randint(40,99,size=[5])
})

# %%
persons
# Out:
#    age     name  percent
# 0    5  Shahzad       43
# 1   34     Taha       92
# 2    2   Fatima       86
# 3   32     Asad       77
# 4    2      Ali       44

# %%
def a(age):
    if age < 18:
        return 'Not Adult'
    else:
        return 'Adult'

# %%
persons['Status'] = persons['age'].apply(a)

# %%
persons
# Out:
#    age     name  percent     Status
# 0    5  Shahzad       43  Not Adult
# 1   34     Taha       92      Adult
# 2    2   Fatima       86  Not Adult
# 3   32     Asad       77      Adult
# 4    2      Ali       44  Not Adult

# %%
def b(percent):
    if percent > 50:
        return 'Good Result'
    else:
        return 'Bad Result'

# %%
persons['Result'] = persons['percent'].apply(b)

# %%
persons
# Out:
#    age     name  percent     Status       Result
# 0    5  Shahzad       43  Not Adult   Bad Result
# 1   34     Taha       92      Adult  Good Result
# 2    2   Fatima       86  Not Adult  Good Result
# 3   32     Asad       77      Adult  Good Result
# 4    2      Ali       44  Not Adult   Bad Result

# %%
data.groupby(['Quiz 1','Quiz 2']).count()
# Out:
#                Student Code  Degree  Student Name  Mid  Best of Quizzes  \
# Quiz 1 Quiz 2
# 4.0    2.0                1       1             1    1                1
#        4.0                1       1             1    1                1
# 5.0    2.0                2       2             2    2                2
#        4.0                1       1             1    1                1
#        5.0                1       1             1    1                1
#        6.0                2       2             2    2                2
# 6.0    6.0                2       2             2    2                2
# 7.0    1.0                1       1             1    1                1
#        2.0                1       1             1    1                1
#        4.0                1       1             1    1                1
#        5.0                3       3             3    3                3
#        6.0                4       4             4    4                4
# ...

# %%
sum(data.Grade=='A')
# Out:
# 8

# %%
data[data.Grade=='A']
# Out:
#      Student_Code  Degree         Student_Name  Mid  Quiz_1  Quiz_2  \
# 7   022-14-110388  BS(CS)     Aneebullah Niazi   26     9.0     6.0
# 9   022-14-110599  BS(CS)              Arsalan   28     8.0     6.0
# 10  022-14-110214  BS(CS)  Fatima Haider Warsi   30     8.0     7.0
# 19  022-14-110222  BS(CS)      Mohammad Hunain   27     9.0     6.0
# 25  022-14-110105  BS(CS)       Muhammad Faraz   26     9.0     6.0
# 34  022-14-110413  BS(CS)     Nazeer Bin Zafar   25     9.0     6.0
# 40  022-14-110584  BS(CS)          Sharif Taqi   27     9.0     6.0
# 45  022-14-110400  BS(CS)    Syeda Sabika Raza   27     9.0     6.0
#
#     Best_of_Quizzes  Assignment_1  Assignment_2  Best_of_Assignments  \
# 7                 9           8.0          10.0                   10
# 9                 8           8.0           NaN                    8
# 10                8           8.0           NaN                    8
# 19                9           8.0          10.0                   10
# ...

# %%
data[(data['Grade']=='A') & (data['Student Name'].str.startswith('A'))]
# Out:
#     Student Code  Degree      Student Name  Mid  Quiz 1  Quiz 2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 7                    45        40.0           85     A
# 9                    44        40.0           84     A

# %%
data[(data['Grade']=='A') & (data['Total (100)']>=70) & (data['Student Name'].str.startswith('S')) & (data['Mid']>=7)]
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 40                9           8.0          10.0                   10
# 45                9           9.0           NaN                    9
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 40                    46        35.0           81     A
# 45                    45        35.0           80     A

# %%
data[data['Best of Assignments']>5]
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# ...

# %%
data[data.Mid<20]
# Out:
#      Student Code  Degree               Student Name  Mid  Quiz 1  Quiz 2  \
# 1   022-14-110233  BS(CS)                Adeel Ahmed   17     NaN     5.0
# 2   022-14-110585  BS(CS)               Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)             Ahmed Ali Raza   14     7.0     2.0
# 8   022-14-110601  BS(CS)             Areesha Sohail   19     9.0     4.0
# 15   022-14-19916  BS(CS)               Haseeb Sajid   18     NaN     NaN
# 18  022-14-110223  BS(CS)              Madiha Jabeen   16     5.0     2.0
# 29  022-14-110217  BS(CS)  Muhammad Shahroz Khurshid   17     7.0     1.0
# 32  022-14-110035  BS(CS)      Muhammad Wajahat Khan    9     NaN     2.0
# 38  022-14-110229  BS(CS)           Sadaquat Rafique    9     6.0     6.0
# 47  022-14-110219  BS(CS)                Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 1                 5           8.0          10.0                   10
# ...

# %%
data[data.Mid>27].count()
# Out:
# Student Code            9
# Degree                  9
# Student Name            9
# Mid                     9
# Quiz 1                  9
# Quiz 2                  9
# Best of Quizzes         9
# Assignment 1            9
# Assignment 2            6
# Best of Assignments     9
# Total Sessional (50)    9
# Final (50)              9
# Total (100)             9
# Grade                   9
# dtype: int64

# %%
data.iloc[5]
# Out:
# Student Code            022-14-110232
# Degree                         BS(CS)
# Student Name              Ameer Hamza
# Mid                                25
# Quiz 1                              9
# Quiz 2                              6
# Best of Quizzes                     9
# Assignment 1                        8
# Assignment 2                       10
# Best of Assignments                10
# Total Sessional (50)               44
# Final (50)                         27
# Total (100)                        71
# Grade                               B
# Name: 5, dtype: object

# %%
data.loc[6]
# Out:
# Student Code            022-14-110588
# Degree                         BS(CS)
# Student Name            Anas Ali Khan
# Mid                                28
# Quiz 1                              5
# Quiz 2                              6
# Best of Quizzes                     6
# Assignment 1                        8
# Assignment 2                       10
# Best of Assignments                10
# Total Sessional (50)               44
# Final (50)                         30
# Total (100)                        74
# Grade                               B
# Name: 6, dtype: object

# %%
data[data['Student Name'] == 'Madiha Jabeen']
# Out:
#      Student Code  Degree   Student Name  Mid  Quiz 1  Quiz 2  \
# 18  022-14-110223  BS(CS)  Madiha Jabeen   16     5.0     2.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 18                5           8.0          10.0                   10
#
#     Total Sessional (50)  Final (50)  Total (100) Grade
# 18                    31        29.0           60     C

# %%
data['Assignment 2'][3:8]
# Out:
# 3     2.0
# 4     9.0
# 5    10.0
# 6    10.0
# 7    10.0
# Name: Assignment 2, dtype: float64

# %%
data.iloc[[1, 3, 5 , 7 , 8 , 10 , 14]]['Best of Quizzes']
# Out:
# 1     5
# 3     7
# 5     9
# 7     9
# 8     9
# 10    8
# 14    7
# Name: Best of Quizzes, dtype: int64

# %%
data.iloc[[2,4,5,6,7,8,9,0,3,1]]['Assignment 2']
# Out:
# 2    10.0
# 4     9.0
# 5    10.0
# 6    10.0
# 7    10.0
# 8     9.0
# 9     NaN
# 0     9.0
# 3     2.0
# 1    10.0
# Name: Assignment 2, dtype: float64

# %%
data1 = data.loc[:, ['Student Code']:"Grade"]
data1.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-56e311f08739> in <module>()
# ----> 1 data1 = data.loc[:, ['Student Code']:"Grade"]
#       2 data1.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1365             except (KeyError, IndexError):
#    1366                 pass
# -> 1367             return self._getitem_tuple(key)
#    1368         else:
#    1369             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     876                 continue
#     877
# --> 878             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     879
#     880         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1579         if isinstance(key, slice):
# ...

# %%
print(data.shape)
# Out:
# (48, 14)

# %%
del data['Assignment_1']
data.head()
# Out:
#     Student_Code  Degree     Student_Name  Mid  Quiz_1  Quiz_2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best_of_Quizzes  Assignment_2  Best_of_Assignments  Total_Sessional_(50)  \
# 0                8           9.0                    9                    45
# 1                5          10.0                   10                    32
# 2                5          10.0                   10                    33
# 3                7           2.0                    2                    23
# 4                7           9.0                    9                    43
#
#    Final (50)  Total (100) Grade
# 0        25.0           70     B
# 1        18.0           50     F
# ...

# %%
data.iloc[0:3 ,:] = np.nan
data.head()
# Out:
#     Student_Code  Degree     Student_Name   Mid  Quiz_1  Quiz_2  \
# 0            NaN     NaN              NaN   NaN     NaN     NaN
# 1            NaN     NaN              NaN   NaN     NaN     NaN
# 2            NaN     NaN              NaN   NaN     NaN     NaN
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza  14.0     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra  27.0     7.0     6.0
#
#    Best_of_Quizzes  Assignment_2  Best_of_Assignments  Total_Sessional_(50)  \
# 0              NaN           NaN                  NaN                   NaN
# 1              NaN           NaN                  NaN                   NaN
# 2              NaN           NaN                  NaN                   NaN
# 3              7.0           2.0                  2.0                  23.0
# 4              7.0           9.0                  9.0                  43.0
#
#    Final (50)  Total (100) Grade
# 0         NaN          NaN   NaN
# 1         NaN          NaN   NaN
# ...

# %%
data = data.dropna(how='any')
data.head()
# Out:
#     Student_Code  Degree      Student_Name   Mid  Quiz_1  Quiz_2  \
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza  14.0     7.0     2.0
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra  27.0     7.0     6.0
# 5  022-14-110232  BS(CS)       Ameer Hamza  25.0     9.0     6.0
# 6  022-14-110588  BS(CS)     Anas Ali Khan  28.0     5.0     6.0
# 7  022-14-110388  BS(CS)  Aneebullah Niazi  26.0     9.0     6.0
#
#    Best_of_Quizzes  Assignment_2  Best_of_Assignments  Total_Sessional_(50)  \
# 3              7.0           2.0                  2.0                  23.0
# 4              7.0           9.0                  9.0                  43.0
# 5              9.0          10.0                 10.0                  44.0
# 6              6.0          10.0                 10.0                  44.0
# 7              9.0          10.0                 10.0                  45.0
#
#    Final (50)  Total (100) Grade
# 3        23.0         46.0     F
# 4        34.0         77.0     B
# ...

# %%
data.shape
# Out:
# (30, 13)

# %%
data[(data.Student_Name.str.startswith('A')) & (data['Grade'] == 'A')]
# Out:
#     Student_Code  Degree      Student_Name  Mid  Quiz_1  Quiz_2  \
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best_of_Quizzes  Assignment_1  Assignment_2  Best_of_Assignments  \
# 7                9           8.0          10.0                   10
# 9                8           8.0           NaN                    8
#
#    Total_Sessional_(50)  Final (50)  Total (100) Grade
# 7                    45        40.0           85     A
# 9                    44        40.0           84     A

# %%
data.groupby('Grade').count()
# Out:
#        Student_Code  Degree  Student_Name  Mid  Quiz_1  Quiz_2  \
# Grade
# A                 8       8             8    8       8       8
# B                16      16            16   16      16      16
# C                13      13            13   13      13      11
# F                11      11            11   11       8      10
#
#        Best_of_Quizzes  Assignment_1  Assignment_2  Best_of_Assignments  \
# Grade
# A                    8             8             5                    8
# B                   16            16            11                   16
# C                   13            12            12                   13
# F                   11             9             8                   11
#
#        Total_Sessional_(50)  Final (50)  Total (100)
# Grade
# A                         8           8            8
# B                        16          16           16
# C                        13          13           13
# ...

# %%
data[['Student_Name','Mid', 'Grade']][(data.Grade == 'A')]
# Out:
#         Student_Name   Mid Grade
# 7   Aneebullah Niazi  26.0     A
# 19   Mohammad Hunain  27.0     A
# 25    Muhammad Faraz  26.0     A
# 34  Nazeer Bin Zafar  25.0     A
# 40       Sharif Taqi  27.0     A

# %%
data[(data.Best_of_Quizzes == 9) & (data.Grade == 'A')]
# Out:
#      Student_Code  Degree       Student_Name  Mid  Quiz_1  Quiz_2  \
# 7   022-14-110388  BS(CS)   Aneebullah Niazi   26     9.0     6.0
# 19  022-14-110222  BS(CS)    Mohammad Hunain   27     9.0     6.0
# 25  022-14-110105  BS(CS)     Muhammad Faraz   26     9.0     6.0
# 34  022-14-110413  BS(CS)   Nazeer Bin Zafar   25     9.0     6.0
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
#
#     Best_of_Quizzes  Assignment_1  Assignment_2  Best_of_Assignments  \
# 7                 9           8.0          10.0                   10
# 19                9           8.0          10.0                   10
# 25                9           8.0          10.0                   10
# 34                9           8.0          10.0                   10
# 40                9           8.0          10.0                   10
# 45                9           9.0           NaN                    9
#
# ...

# %%
data[data.Student_Name.str.contains(' Ali ')]
# Out:
#     Student_Code  Degree     Student_Name   Mid  Quiz_1  Quiz_2  \
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza  14.0     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra  27.0     7.0     6.0
# 6  022-14-110588  BS(CS)    Anas Ali Khan  28.0     5.0     6.0
#
#    Best_of_Quizzes  Assignment_2  Best_of_Assignments  Total_Sessional_(50)  \
# 3              7.0           2.0                  2.0                  23.0
# 4              7.0           9.0                  9.0                  43.0
# 6              6.0          10.0                 10.0                  44.0
#
#    Final (50)  Total (100) Grade
# 3        23.0         46.0     F
# 4        34.0         77.0     B
# 6        30.0         74.0     B

# %%
data[data.Student_Name.str.endswith('Hamza')]
# Out:
#     Student_Code  Degree Student_Name   Mid  Quiz_1  Quiz_2  Best_of_Quizzes  \
# 5  022-14-110232  BS(CS)  Ameer Hamza  25.0     9.0     6.0              9.0
#
#    Assignment_2  Best_of_Assignments  Total_Sessional_(50)  Final (50)  \
# 5          10.0                 10.0                  44.0        27.0
#
#    Total (100) Grade
# 5         71.0     B

# %%
persons = pd.DataFrame({
    'name': ['Shahzad' , 'Taha' , 'Fatima' , 'Khani' , 'Samia'],
    'age': np.random.randint(1,40, size = [5]),
    'percent': np.random.randint(40,90, size = [5])
    
})

# %%
persons
# Out:
#       name  age  percent
# 0  Shahzad   29       46
# 1     Taha   10       87
# 2   Fatima   12       67
# 3    Khani   36       56
# 4    Samia   31       46

# %%
def a(age):
    if age < 18:
        return 'Non-Adult'
    else:
        return 'Adult'

# %%
persons['Status'] = persons['age'].map(a) #We can use 'apply' also

# %%
persons
# Out:
#       name  age  percent     Status
# 0  Shahzad   29       46      Adult
# 1     Taha   10       87  Non-Adult
# 2   Fatima   12       67  Non-Adult
# 3    Khani   36       56      Adult
# 4    Samia   31       46      Adult
